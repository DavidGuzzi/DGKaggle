# %% [markdown]
# ## **Datos de la competencia.**
#
# [Playground Series - Season 6, Episode 9: Predicting Electric Vehicle Purchases](https://kaggle.com/competitions/playground-series-s6e9)
#
# Requisitos previos:
# - Credenciales de la API en `~/.kaggle/kaggle.json`.
# - Reglas de la competencia aceptadas en la web (si no, la CLI devuelve 403).

# %%
import sys
# !{sys.executable} -m pip install kaggle
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.2.1
# [notice] To update, run: C:\Users\HP\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip
# ...

# %%
import os
import zipfile

DATA_DIR = "../data"
COMPETITION = "playground-series-s6e9"

os.makedirs(DATA_DIR, exist_ok=True)

# !kaggle competitions download -c {COMPETITION} -p {DATA_DIR}

# Descomprimir el archivo descargado
zip_path = os.path.join(DATA_DIR, f"{COMPETITION}.zip")
if os.path.exists(zip_path):
    with zipfile.ZipFile(zip_path, "r") as z:
        z.extractall(DATA_DIR)
    os.remove(zip_path)
    print("Datos extraidos y zip eliminado.")
else:
    print("No se encontro el zip. Verificar credenciales y nombre de competencia.")
# Out:
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
#   7%|▋         | 1.00M/14.1M [00:00<00:10, 1.28MB/s]
#  14%|█▍        | 2.00M/14.1M [00:00<00:04, 2.54MB/s]
#  28%|██▊       | 4.00M/14.1M [00:01<00:01, 5.35MB/s]
#  50%|████▉     | 7.00M/14.1M [00:01<00:00, 9.83MB/s]
#  71%|███████   | 10.0M/14.1M [00:01<00:00, 14.2MB/s]
#  99%|█████████▉| 14.0M/14.1M [00:02<00:00, 6.92MB/s]
# 100%|██████████| 14.1M/14.1M [00:02<00:00, 5.11MB/s]
# ...
# Datos extraidos y zip eliminado.

# %%
# Verificar archivos descargados
for f in os.listdir(DATA_DIR):
    size_mb = os.path.getsize(os.path.join(DATA_DIR, f)) / (1024 * 1024)
    print(f"{f:40s} {size_mb:.2f} MB")
# Out:
# .gitkeep                                 0.00 MB
# sample_submission.csv                    7.38 MB
# test.csv                                 17.45 MB
# train.csv                                42.64 MB
